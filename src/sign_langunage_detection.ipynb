# %%
# !nvidia-smi
# Out:
# Sun Nov 30 10:09:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.52                 Driver Version: 576.52         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce MX330         WDDM  |   00000000:02:00.0 Off |                  N/A |
# | N/A   59C    P8            N/A  / 5001W |     126MiB /   2048MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           13684    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           20632    C+G   ...Browser\Application\brave.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt  # install YOLOv5 dependencies

# Verify installation
import torch
from IPython.display import Image
print(f'YOLOv5 setup complete. Using PyTorch {torch.__version__}')
# Out:
# f:\University of Ruhuna\Uni_Project\sign_language_detection_YOLO\src\yolov5
# Cloning into 'yolov5'...
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 get_ipython().system('pip install -qr requirements.txt  # install YOLOv5 dependencies')
#       6 # Verify installation
# ----> 7 import torch
#       8 from IPython.display import Image
#       9 print(f'YOLOv5 setup complete. Using PyTorch {torch.__version__}')
#
# ModuleNotFoundError: No module named 'torch'

# %%
pwd

# %%
# %cd /content

# %%
import gdown
