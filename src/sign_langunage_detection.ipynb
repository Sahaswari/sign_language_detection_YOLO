# %%
# !nvidia-smi
# Out:
# Sun Nov 30 10:09:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.52                 Driver Version: 576.52         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce MX330         WDDM  |   00000000:02:00.0 Off |                  N/A |
# | N/A   59C    P8            N/A  / 5001W |     126MiB /   2048MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# f:\University of Ruhuna\Uni_Project\sign_language_detection_YOLO\src\yolov5
# Cloning into 'yolov5'...

# %%
# %pwd
# Out:
# 'f:\\University of Ruhuna\\Uni_Project\\sign_language_detection_YOLO\\src\\yolov5'

# %%
# !pip install -qr requirements.txt

# %%
# Verify installation
# !pip install torch
import torch
from IPython.display import Image
print(f'YOLOv5 setup complete. Using PyTorch {torch.__version__}')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Verify installation
#       2 get_ipython().system('pip install torch')
# ----> 3 import torch
#       4 from IPython.display import Image
#       5 print(f'YOLOv5 setup complete. Using PyTorch {torch.__version__}')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
# ...

# %%
pwd

# %%
# %cd /content

# %%
import gdown

# %%
#unzip

# !unzip sign_data.zip
